# %%
df = pd.read_csv('CollegeRookieStatLog2_temp.csv')
df.head()
# Out:
#              Name                  School      G     GS    MP   FG   FGA  \
# 0    Mike Higgins                    Navy   60.0    2.0   9.0  1.1   2.3
# 1    Ashraf Amaya       Southern Illinois  128.0  120.0  32.2  5.3   9.4
# 2    James Cotton  Maryland-Eastern Shore   19.0    3.0  13.9  0.8   1.8
# 3  Eddie Robinson                   Lamar  114.0   75.0  32.6  1.8   4.9
# 4  Gilbert Arenas                 Arizona   70.0   33.0  30.5  5.6  12.1
#
#      FG%   2P  2PA  ...  Pos_x  Age_x  Year_y  Pos_y  Age_y  NBATRB  NBAAST  \
# 0  0.464  0.9  1.7  ...    NaN     22    1990     SF     22     0.4     0.3
# 1  0.567  5.2  9.0  ...    NaN     24    1996     PF     24     5.6     0.6
# 2  0.441  0.8  1.7  ...    NaN     22    1998     SG     22     0.7     0.0
# 3  0.365  1.5  3.8  ...    NaN     23    2000     SF     23     2.7     0.5
# 4  0.466  4.1  7.9  ...    NaN     20    2002     PG     20     2.8     3.7
#
#    NBASTL  NBABLK  NBAPTS
# 0     0.2     0.2     1.3
# ...

# %%
df = df.drop(['Year_x','Pos_x','Age_x'], axis=1)
df.head()
# Out:
#              Name                  School      G     GS    MP   FG   FGA  \
# 0    Mike Higgins                    Navy   60.0    2.0   9.0  1.1   2.3
# 1    Ashraf Amaya       Southern Illinois  128.0  120.0  32.2  5.3   9.4
# 2    James Cotton  Maryland-Eastern Shore   19.0    3.0  13.9  0.8   1.8
# 3  Eddie Robinson                   Lamar  114.0   75.0  32.6  1.8   4.9
# 4  Gilbert Arenas                 Arizona   70.0   33.0  30.5  5.6  12.1
#
#      FG%   2P  2PA  ...   PTS    SOS  Year_y  Pos_y  Age_y  NBATRB  NBAAST  \
# 0  0.464  0.9  1.7  ...   3.2  -5.93    1990     SF     22     0.4     0.3
# 1  0.567  5.2  9.0  ...  14.6   0.74    1996     PF     24     5.6     0.6
# 2  0.441  0.8  1.7  ...   2.9  -7.38    1998     SG     22     0.7     0.0
# 3  0.365  1.5  3.8  ...   5.2  -7.20    2000     SF     23     2.7     0.5
# 4  0.466  4.1  7.9  ...  15.8  11.13    2002     PG     20     2.8     3.7
#
#    NBASTL  NBABLK  NBAPTS
# 0     0.2     0.2     1.3
# ...

# %%
df.columns
# Out:
# Index(['Name', 'School', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA',
#        '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'SOS', 'Year_y', 'Pos_y',
#        'Age_y', 'NBATRB', 'NBAAST', 'NBASTL', 'NBABLK', 'NBAPTS'],
#       dtype='object')

# %%
df.rename({'Year_y':'Year','Pos_y':'Pos','Age_y':'Age'}, axis=1, inplace=True)

# %%
df.head()
# Out:
#              Name                  School      G     GS    MP   FG   FGA  \
# 0    Mike Higgins                    Navy   60.0    2.0   9.0  1.1   2.3
# 1    Ashraf Amaya       Southern Illinois  128.0  120.0  32.2  5.3   9.4
# 2    James Cotton  Maryland-Eastern Shore   19.0    3.0  13.9  0.8   1.8
# 3  Eddie Robinson                   Lamar  114.0   75.0  32.6  1.8   4.9
# 4  Gilbert Arenas                 Arizona   70.0   33.0  30.5  5.6  12.1
#
#      FG%   2P  2PA  ...   PTS    SOS  Year  Pos  Age  NBATRB  NBAAST  NBASTL  \
# 0  0.464  0.9  1.7  ...   3.2  -5.93  1990   SF   22     0.4     0.3     0.2
# 1  0.567  5.2  9.0  ...  14.6   0.74  1996   PF   24     5.6     0.6     0.4
# 2  0.441  0.8  1.7  ...   2.9  -7.38  1998   SG   22     0.7     0.0     0.1
# 3  0.365  1.5  3.8  ...   5.2  -7.20  2000   SF   23     2.7     0.5     0.7
# 4  0.466  4.1  7.9  ...  15.8  11.13  2002   PG   20     2.8     3.7     1.5
#
#    NBABLK  NBAPTS
# 0     0.2     1.3
# 1     0.2     6.3
# ...

# %%
df.to_csv('CollegeRookieStatLog2.csv')
